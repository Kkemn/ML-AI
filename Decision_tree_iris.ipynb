# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# %%
iris = datasets.load_iris()
feature_names = iris['feature_names'][2:]
X = iris.data[:, 2:]
y = iris.target
target_names = iris.target_names
target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123, stratify=y)

# %%
tree = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=123)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=123)

# %%
plot_tree(tree, feature_names=feature_names, class_names=target_names, filled=True)
# Out:
# [Text(0.375, 0.875, 'petal length (cm) <= 2.45\nentropy = 1.585\nsamples = 105\nvalue = [35, 35, 35]\nclass = setosa'),
#  Text(0.25, 0.625, 'entropy = 0.0\nsamples = 35\nvalue = [35, 0, 0]\nclass = setosa'),
#  Text(0.3125, 0.75, 'True  '),
#  Text(0.5, 0.625, 'petal length (cm) <= 4.75\nentropy = 1.0\nsamples = 70\nvalue = [0, 35, 35]\nclass = versicolor'),
#  Text(0.4375, 0.75, '  False'),
#  Text(0.25, 0.375, 'petal width (cm) <= 1.65\nentropy = 0.196\nsamples = 33\nvalue = [0, 32, 1]\nclass = versicolor'),
#  Text(0.125, 0.125, 'entropy = 0.0\nsamples = 32\nvalue = [0, 32, 0]\nclass = versicolor'),
#  Text(0.375, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.75, 0.375, 'petal length (cm) <= 5.15\nentropy = 0.406\nsamples = 37\nvalue = [0, 3, 34]\nclass = virginica'),
#  Text(0.625, 0.125, 'entropy = 0.779\nsamples = 13\nvalue = [0, 3, 10]\nclass = virginica'),
# ...

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree_reg = DecisionTreeRegressor(max_depth=3, random_state=123)
tree_reg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=123)

# %%
plot_tree(tree_reg, feature_names=feature_names, class_names=target_names, filled=True)
# Out:
# [Text(0.375, 0.875, 'petal length (cm) <= 2.45\nsquared_error = 0.667\nsamples = 105\nvalue = 1.0'),
#  Text(0.25, 0.625, 'squared_error = 0.0\nsamples = 35\nvalue = 0.0'),
#  Text(0.3125, 0.75, 'True  '),
#  Text(0.5, 0.625, 'petal length (cm) <= 4.75\nsquared_error = 0.25\nsamples = 70\nvalue = 1.5'),
#  Text(0.4375, 0.75, '  False'),
#  Text(0.25, 0.375, 'petal width (cm) <= 1.65\nsquared_error = 0.029\nsamples = 33\nvalue = 1.03'),
#  Text(0.125, 0.125, 'squared_error = 0.0\nsamples = 32\nvalue = 1.0'),
#  Text(0.375, 0.125, 'squared_error = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(0.75, 0.375, 'petal length (cm) <= 4.95\nsquared_error = 0.075\nsamples = 37\nvalue = 1.919'),
#  Text(0.625, 0.125, 'squared_error = 0.24\nsamples = 5\nvalue = 1.6'),
#  Text(0.875, 0.125, 'squared_error = 0.03\nsamples = 32\nvalue = 1.969')]
